# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
movie_title = ['Spdier-Man', 'Mogadishu', 'Eternals', 'Black widow', 'Fast&Furious9']
audience = [7541456, 3613981, 3050518, 2962088, 2292413]
data = {'Movie' : movie_title, 'Audience' : audience}
df = pd.DataFrame(data)

# %%
sns.barplot(data = df, x = 'Movie', y = 'Audience')
